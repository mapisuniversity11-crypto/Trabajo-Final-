# %% [markdown]
# # 🧩 Ejercicio 1: Uso básico de métodos de instancia
#
# Crear una clase `Persona` con:
#
# ## Atributos:
# * **nombre**
# * **edad**
#
# ## Métodos:
# * `saludar()`: imprime "Hola, soy {nombre}"
# * `es_mayor_de_edad()`: retorna `True` si edad >= 18, de lo contrario `False`
#
# ---
#
# ## Prueba:
#
# ```python
# p = Persona("Ana", 20)
#
# p.saludar()                  # Hola, soy Ana
# print(p.es_mayor_de_edad())  # True

# %% [markdown]
# # 🧩 Ejercicio 2: Métodos que modifican el estado
#
# Crear una clase `Cuenta` con:
#
# ## Atributos:
# * **titular**
# * **saldo**
#
# ## Métodos:
# * `depositar(cantidad)`: aumenta el saldo
# * `retirar(cantidad)`: disminuye el saldo solo si hay suficiente dinero
# * `consultar_saldo()`: retorna el saldo actual
#
# ---
#
# ## Prueba:
#
# ```python
# c = Cuenta("Luis", 1000)
#
# c.depositar(500)
# c.retirar(300)
#
# print(c.consultar_saldo()) # 1200

# %% [markdown]
# # 🧩 Ejercicio 3: Métodos con lógica
#
# Crear una clase `Rectangulo` con:
#
# ## Atributos:
# * **base**
# * **altura**
#
# ## Métodos:
# * `area()`: retorna el área
# * `perimetro()`: retorna el perímetro
# * `es_cuadrado()`: retorna `True` si base == altura
#
# ---
#
# ## Prueba:
#
# ```python
# r = Rectangulo(4, 4)
#
# print(r.area())           # 16
# print(r.perimetro())      # 16
# print(r.es_cuadrado())    # True

# %% [markdown]
# # 🏦 Ejercicio 4: Implementación de un Cajero Automático
#
# Queremos implementar un cajero que inicie con billetes de denominación `10.000`, `20.000` y `50.000`, y sea capaz de retornar la cantidad dada por un usuario.
#
# La clase `Cajero` tiene los siguientes métodos:
#
# ## Métodos:
#
# * `__init__(self, n1, n2, n3)`: Tiene la configuración inicial del cajero donde `ni` representa la cantidad de billetes del cajero (de 10k, 20k y 50k respectivamente).
# * `retirar(self, cantidad)`: Este método debe:
#     * Verificar que le puede retornar la cantidad indicada de dinero al usuario.
#     * Actualizar la cantidad de billetes dentro del cajero (es decir, actualizar sus atributos).
#
# ---
#
# ## Ejemplo de uso sugerido:
#
# ```python
# # Inicializamos con 10 billetes de cada denominación
# mi_cajero = Cajero(10, 10, 10)
#
# # Intentamos retirar una cantidad
# mi_cajero.retirar(130000)
